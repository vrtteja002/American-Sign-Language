# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (16 CPUs, 62.8 GB RAM, 28.8/201.2 GB disk)

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !curl -L "https://app.roboflow.com/ds/L6Um93kmwp?key=ir5IhEpxPC" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/labels/bharaniNeu_0492_jpg.rf.4a12149ca1c638550ae03e20417eabd1.txt
#  extracting: train/labels/bharaniNeu_0495_jpg.rf.cdf82041637f19f2e6edbb4d7b377000.txt
#  extracting: train/labels/bharaniNeu_0501_jpg.rf.8d359b49427f86f9c65dc07d8d401ac6.txt
#  extracting: train/labels/bharaniNeu_0507_jpg.rf.05130a58f7e32ec8851cee22f8ffca7d.txt
#  extracting: train/labels/bharaniNeu_0516_jpg.rf.ea33b60ad38f845866687c161a27fe0f.txt
#  extracting: train/labels/bharaniNeu_0564_jpg.rf.57780c11e1da50ecf102fbc86ca9c197.txt
#  extracting: train/labels/bharaniNeu_0584_jpg.rf.4b37621d1da467d08e163bb409459a8a.txt
#  extracting: train/labels/bharaniNeu_0595_jpg.rf.f9ecfea342f6db29cfbc813c0831859e.txt
#  extracting: train/labels/bharaniNeu_0596_jpg.rf.deb9189760178043ab8575c0314325d4.txt
#  extracting: train/labels/bharaniNeu_0616_jpg.rf.a108980ce05abd4b5bb7be3b0fa1cfd3.txt
# ...

# %%
root_dir="/content"

# %%
import os
model = YOLO('yolov8n.pt')
results = model.train(data=os.path.join(root_dir,'data.yaml'),epochs=100,save=True)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 110MB/s]
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...
